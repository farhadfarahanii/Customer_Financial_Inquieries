# %% [markdown]
# # Machine Learning Model Selection for Customer Inquiry Classification
# To accurately classify customer inquiries in the banking industry, we implemented multiple machine learning models to find the best-performing algorithm. The models were trained on SBERT embeddings generated from customer inquiries and optimized using hyperparameter tuning.

# %% [markdown]
# >[Machine Learning Model Selection for Customer Inquiry Classification](#scrollTo=VZhgkoITtV3Z)
#
# >>[Imports](#scrollTo=fwDBl0VKtZ_B)
#
# >>[Load Data](#scrollTo=YK4_CdUJ-YDn)
#
# >>[Baseline Score](#scrollTo=l3PrfoEdBS4U)
#
# >>>[Baseline Accuracy](#scrollTo=CMQi0-ShCQeV)
#
# >>[Fine Tuning with GridSearch](#scrollTo=FIJYTL54FD3A)
#
# >>[XGBoost Model](#scrollTo=rgD_4oXw-HlH)
#
# >>[CatBoost Model](#scrollTo=-vBM9qBL-TZh)
#
# >>[MLPClassifier](#scrollTo=t8uKLFs2-dso)
#
# >>[Deep Neural Network (DNN)](#scrollTo=AfxiLFBwBMKO)
#
# >>[Summary](#scrollTo=xGUvKOEBfQtM)

# %% [markdown]
# ## Imports

# %%
# !pip install --upgrade scikit-learn
# !pip install --upgrade xgboost scikit-learn
# !pip install catboost
# !pip install scikeras tensorflow



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from collections import Counter
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier

from scikeras.wrappers import KerasClassifier

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

from sklearn.metrics import classification_report

import joblib
import os
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Mount to drive
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Load Data

# %%
data_path = 'drive/MyDrive/Colab_Notebooks/financial_customer_inq/data/final_data.csv'

embeddings_path = 'drive/MyDrive/Colab_Notebooks/financial_customer_inq/data/embeddings.npy'

# %%
# Load the final dataset
df = pd.read_csv(data_path)

# Load the embedding
embeddings = np.load(embeddings_path)

# %%
# Display the size of the dataset: {df.shape[0]}")
print(f"Number of features: {df.shape[1]}\n\n")
df.head()
# Out:
# Number of features: 6
#                               conversation_id  \
# 0  acs-00051ccd-7f2b-4b4d-85dc-f716c7e9f34f-1
# 1  acs-000e0b37-c8f0-46fe-9ffb-0c727e888339-1
# 2  acs-000efddb-1d74-4422-808e-1b4ccbf988f1-1
# 3  acs-001df2c1-5318-4715-8d99-7ece76c95fa2-1
# 4  acs-002c64ef-f434-41cd-8c36-39c4d8b9cd30-1
#
#                                            utterance  sentiment_score  \
# 0  agent: hey may help today customer: hi want ch...           0.9896
# 1  agent: hellohow may help today customer: hi ne...           0.9977
# 2  customer: good morning agent: good morning may...           0.9926
# 3  agent: hello customer: hello jamie customer: n...           0.9961
# 4  customer: hi agent: hello may help today custo...           0.9943
#
#    cluster                                  cleaned_utterance  \
# 0        0  : hey may  today :  want change address associ...
# 1        0  : hellohow may  today :  need  remove unwanted...
# 2        1  : good  : good  may  today : lost card safe mo...
# 3        0  :  :  jamie : najma : good  may assist today :...
# 4        2  :  :  may  today : want transfer money another...
#
#                                topic
# 0  credit card charge/address update
# 1  credit card charge/address update
# 2         lost or stolen credit card
# 3  credit card charge/address update
# 4             money transfer request

# %% [markdown]
# ## Baseline Score

# %%
# Define X (features) and y(target)
X = embeddings

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df["topic"])  # Convert topics to numbers

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
print(f"X shape ---------- {X.shape}")
print(f"y shape ---------- {y.shape}")
# Out:
# X shape ---------- (8832, 384)
# y shape ---------- (8832,)

# %% [markdown]
# ### Baseline Accuracy

# %%
# Calculate the frequency of each class in the topic
class_frequencies = Counter(y_train)  # Using y_train for baseline calculation

# Get the most frequent class
most_frequent_class = class_frequencies.most_common(1)[0][0]

# Calculate baseline accuracy
baseline_accuracy = class_frequencies[most_frequent_class] / len(y_train)

print(f"Baseline Accuracy: {baseline_accuracy}")
# Out:
# Baseline Accuracy: 0.35778985507246375

# %% [markdown]
# ## Fine Tuning with GridSearch
#
# To improve the accuracy and performance of our customer inquiry classification models, we performed hyperparameter tuning using GridSearchCV. This process systematically tests different model configurations to find the optimal settings for each algorithm.
#
# We applied GridSearchCV to the following models:
#
# - Logistic Regression
# - Support Vector Machine (SVC)
# - Random Forest
# - Gradient Boosting
# - LGBM Classifier

# %%
# Define hyperparameter grids
param_grids = {
    "LogisticRegression": {
        "C": [0.1, 1, 10, 100],
        "solver": ["lbfgs", "newton-cg", "saga"],
        "max_iter": [500, 1000]
    },
    "SVC": {
        "C": [0.1, 1, 10],
        "kernel": ["linear", "rbf"],
        "gamma": ["scale", "auto"]
    },
    "RandomForestClassifier": {
        "n_estimators": [50, 100],
        "max_depth": [None, 10, 20],
        "min_samples_split": [2, 5, 10]
    },
    #"GradientBoostingClassifier": {
    #    "n_estimators": [100],                  # Had to cancel this model because of project timing
    #    "max_depth": [3, 5],
    #    "learning_rate": [0.05, 0.1]
   # },
    "LGBMClassifier" : {
        "n_estimators": [100, 200],
        "max_depth": [3, 5],
        "learning_rate": [0.01, 0.1],
        "subsample": [0.7, 0.9],
        "colsample_bytree": [0.7, 0.9]
}
}

# %%
# Models to evaluate
models = {
    "LogisticRegression": LogisticRegression(multi_class="multinomial"),
    "SVC": SVC(),
    "RandomForestClassifier": RandomForestClassifier(),
    #"GradientBoostingClassifier": GradientBoostingClassifier(), # Had to cancel this model because of project timing
    "LGBMClassifier": LGBMClassifier(objective="multiclass")
    }

# %%
# Define the directory path
save_dir = '/content/drive/MyDrive/Colab_Notebooks/financial_customer_inq/models/'

# Create the directory
os.makedirs(save_dir, exist_ok=True)

# Dictionary to store best models
best_models = {}

# Perform GridSearchCV for each model
for model_name, model in models.items():
    print(f"Running GridSearch for {model_name}...")
    grid_search = GridSearchCV(model, param_grids[model_name], cv=5, scoring="accuracy", n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_models[model_name] = grid_search.best_estimator_

    # Save model
    joblib.dump(grid_search.best_estimator_, os.path.join(save_dir, f"{model_name}_best_model.pkl"))

    # Print best parameters and score
    print(f"Best Parameters for {model_name}: {grid_search.best_params_}")
    print(f"Best Score: {grid_search.best_score_}\n")
# Out:
# Running GridSearch for LogisticRegression...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Best Parameters for LogisticRegression: {'C': 100, 'max_iter': 1000, 'solver': 'saga'}
# Best Score: 0.9916968591460981
#
# Running GridSearch for SVC...
# Best Parameters for SVC: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Score: 0.9935084079119877
#
# Running GridSearch for RandomForestClassifier...
# Best Parameters for RandomForestClassifier: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score: 0.9814320241691842
#
# Running GridSearch for LGBMClassifier...
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 97920
# [LightGBM] [Info] Number of data points in the train set: 6624, number of used features: 384
# [LightGBM] [Info] Start training from score -5.854016
# [LightGBM] [Info] Start training from score -4.062256
# [LightGBM] [Info] Start training from score -1.027809
# [LightGBM] [Info] Start training from score -3.515251
# [LightGBM] [Info] Start training from score -3.369109
# [LightGBM] [Info] Start training from score -1.399668
# [LightGBM] [Info] Start training from score -1.167023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best Parameters for LGBMClassifier: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.7}
# Best Score: 0.9874703300461724

# %% [markdown]
# ## XGBoost Model

# %%
# Define XGBoost model
xgb = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1, objective="multi:softmax")

# Train model
xgb.fit(X_train, y_train)

# Predict and evaluate
y_pred_xgb = xgb.predict(X_test)

# Save model
joblib.dump(xgb, os.path.join(save_dir, f"xgb_model.pkl"))

print("XGBoost Accuracy:", xgb.score(X_test, y_test))
# Out:
# XGBoost Accuracy: 0.9818840579710145

# %% [markdown]
# ## CatBoost Model

# %%
# Define CatBoost model
cat = CatBoostClassifier(task_type="CPU", iterations=500, depth=6, learning_rate=0.1, loss_function="MultiClass")

# Train model
cat.fit(X_train, y_train)

# Predict and evaluate
y_pred_cat = cat.predict(X_test)

# Save model
joblib.dump(cat, os.path.join(save_dir, f"cat_model.pkl"))

print("CatBoost Accuracy:", cat.score(X_test, y_test))
# Out:
# 0:	learn: 1.5651640	total: 1.43s	remaining: 11m 55s
# 1:	learn: 1.3322840	total: 2.38s	remaining: 9m 52s
# 2:	learn: 1.1710979	total: 3.36s	remaining: 9m 16s
# 3:	learn: 1.0238261	total: 4.35s	remaining: 8m 59s
# 4:	learn: 0.9160066	total: 5.36s	remaining: 8m 50s
# 5:	learn: 0.8282993	total: 6.16s	remaining: 8m 27s
# 6:	learn: 0.7522055	total: 6.72s	remaining: 7m 53s
# 7:	learn: 0.6850857	total: 7.3s	remaining: 7m 29s
# 8:	learn: 0.6275024	total: 7.88s	remaining: 7m 9s
# 9:	learn: 0.5768769	total: 8.47s	remaining: 6m 55s
# 10:	learn: 0.5352684	total: 9.07s	remaining: 6m 43s
# 11:	learn: 0.4950167	total: 9.65s	remaining: 6m 32s
# 12:	learn: 0.4613123	total: 10.2s	remaining: 6m 23s
# 13:	learn: 0.4280224	total: 10.8s	remaining: 6m 14s
# 14:	learn: 0.4026869	total: 11.4s	remaining: 6m 7s
# 15:	learn: 0.3765264	total: 11.9s	remaining: 6m 1s
# 16:	learn: 0.3541340	total: 12.5s	remaining: 5m 55s
# 17:	learn: 0.3343917	total: 13.1s	remaining: 5m 51s
# 18:	learn: 0.3157249	total: 13.7s	remaining: 5m 47s
# 19:	learn: 0.2980298	total: 14.3s	remaining: 5m 43s
# 20:	learn: 0.2814127	total: 14.9s	remaining: 5m 40s
# 21:	learn: 0.2662350	total: 15.5s	remaining: 5m 36s
# 22:	learn: 0.2528254	total: 16.1s	remaining: 5m 33s
# 23:	learn: 0.2402254	total: 17.1s	remaining: 5m 38s
# 24:	learn: 0.2281197	total: 18s	remaining: 5m 41s
# 25:	learn: 0.2181158	total: 19s	remaining: 5m 45s
# 26:	learn: 0.2079739	total: 19.9s	remaining: 5m 48s
# 27:	learn: 0.1993342	total: 20.8s	remaining: 5m 50s
# 28:	learn: 0.1908578	total: 21.4s	remaining: 5m 47s
# 29:	learn: 0.1833906	total: 21.9s	remaining: 5m 43s
# 30:	learn: 0.1761915	total: 22.5s	remaining: 5m 40s
# 31:	learn: 0.1689387	total: 23.1s	remaining: 5m 38s
# 32:	learn: 0.1623026	total: 23.7s	remaining: 5m 35s
# 33:	learn: 0.1571622	total: 24.2s	remaining: 5m 32s
# 34:	learn: 0.1503025	total: 24.8s	remaining: 5m 29s
# 35:	learn: 0.1451655	total: 25.4s	remaining: 5m 26s
# 36:	learn: 0.1403596	total: 25.9s	remaining: 5m 24s
# 37:	learn: 0.1357090	total: 26.5s	remaining: 5m 22s
# 38:	learn: 0.1313598	total: 27.1s	remaining: 5m 20s
# 39:	learn: 0.1272920	total: 27.6s	remaining: 5m 17s
# 40:	learn: 0.1236562	total: 28.2s	remaining: 5m 15s
# 41:	learn: 0.1198044	total: 28.8s	remaining: 5m 13s
# 42:	learn: 0.1171856	total: 29.3s	remaining: 5m 11s
# 43:	learn: 0.1139180	total: 29.9s	remaining: 5m 9s
# 44:	learn: 0.1112185	total: 30.4s	remaining: 5m 7s
# 45:	learn: 0.1080235	total: 31.2s	remaining: 5m 7s
# 46:	learn: 0.1049269	total: 32.2s	remaining: 5m 10s
# 47:	learn: 0.1021918	total: 33.1s	remaining: 5m 11s
# 48:	learn: 0.0999491	total: 34s	remaining: 5m 13s
# 49:	learn: 0.0973902	total: 35s	remaining: 5m 15s
# 50:	learn: 0.0955917	total: 35.7s	remaining: 5m 13s
# 51:	learn: 0.0929111	total: 36.2s	remaining: 5m 12s
# 52:	learn: 0.0909311	total: 36.8s	remaining: 5m 10s
# 53:	learn: 0.0886799	total: 37.3s	remaining: 5m 8s
# 54:	learn: 0.0866483	total: 37.9s	remaining: 5m 6s
# 55:	learn: 0.0848112	total: 38.4s	remaining: 5m 4s
# 56:	learn: 0.0832272	total: 39s	remaining: 5m 2s
# 57:	learn: 0.0815564	total: 39.5s	remaining: 5m 1s
# 58:	learn: 0.0802181	total: 40.1s	remaining: 4m 59s
# 59:	learn: 0.0786335	total: 40.6s	remaining: 4m 57s
# 60:	learn: 0.0773000	total: 41.2s	remaining: 4m 56s
# 61:	learn: 0.0760041	total: 41.8s	remaining: 4m 55s
# 62:	learn: 0.0741738	total: 42.8s	remaining: 4m 56s
# 63:	learn: 0.0729943	total: 43.7s	remaining: 4m 57s
# 64:	learn: 0.0714945	total: 44.7s	remaining: 4m 58s
# 65:	learn: 0.0701892	total: 45.7s	remaining: 5m
# 66:	learn: 0.0690664	total: 46.7s	remaining: 5m 1s
# 67:	learn: 0.0685280	total: 47.7s	remaining: 5m 3s
# 68:	learn: 0.0676094	total: 48.7s	remaining: 5m 3s
# 69:	learn: 0.0664748	total: 49.7s	remaining: 5m 5s
# 70:	learn: 0.0652435	total: 50.7s	remaining: 5m 6s
# 71:	learn: 0.0642222	total: 51.7s	remaining: 5m 7s
# 72:	learn: 0.0628546	total: 52.6s	remaining: 5m 7s
# 73:	learn: 0.0621521	total: 53.5s	remaining: 5m 7s
# 74:	learn: 0.0611173	total: 54.4s	remaining: 5m 8s
# 75:	learn: 0.0596601	total: 55.3s	remaining: 5m 8s
# 76:	learn: 0.0588292	total: 55.9s	remaining: 5m 6s
# 77:	learn: 0.0580072	total: 56.4s	remaining: 5m 5s
# 78:	learn: 0.0569053	total: 57s	remaining: 5m 3s
# 79:	learn: 0.0564197	total: 57.5s	remaining: 5m 2s
# 80:	learn: 0.0555138	total: 58.1s	remaining: 5m
# 81:	learn: 0.0548443	total: 58.6s	remaining: 4m 58s
# 82:	learn: 0.0541113	total: 59.2s	remaining: 4m 57s
# 83:	learn: 0.0536723	total: 59.7s	remaining: 4m 55s
# 84:	learn: 0.0531034	total: 1m	remaining: 4m 54s
# 85:	learn: 0.0525927	total: 1m	remaining: 4m 52s
# 86:	learn: 0.0518490	total: 1m 1s	remaining: 4m 51s
# 87:	learn: 0.0510124	total: 1m 2s	remaining: 4m 51s
# 88:	learn: 0.0503962	total: 1m 3s	remaining: 4m 51s
# 89:	learn: 0.0497846	total: 1m 4s	remaining: 4m 51s
# 90:	learn: 0.0492219	total: 1m 5s	remaining: 4m 52s
# 91:	learn: 0.0488030	total: 1m 5s	remaining: 4m 52s
# 92:	learn: 0.0483482	total: 1m 6s	remaining: 4m 50s
# 93:	learn: 0.0478518	total: 1m 7s	remaining: 4m 49s
# 94:	learn: 0.0472895	total: 1m 7s	remaining: 4m 48s
# 95:	learn: 0.0466468	total: 1m 8s	remaining: 4m 46s
# 96:	learn: 0.0458621	total: 1m 8s	remaining: 4m 45s
# 97:	learn: 0.0453994	total: 1m 9s	remaining: 4m 43s
# 98:	learn: 0.0450407	total: 1m 9s	remaining: 4m 42s
# 99:	learn: 0.0448099	total: 1m 10s	remaining: 4m 40s
# 100:	learn: 0.0443965	total: 1m 10s	remaining: 4m 39s
# 101:	learn: 0.0439411	total: 1m 11s	remaining: 4m 38s
# 102:	learn: 0.0434578	total: 1m 11s	remaining: 4m 36s
# 103:	learn: 0.0430946	total: 1m 12s	remaining: 4m 35s
# 104:	learn: 0.0426179	total: 1m 12s	remaining: 4m 34s
# 105:	learn: 0.0422591	total: 1m 13s	remaining: 4m 33s
# 106:	learn: 0.0420588	total: 1m 14s	remaining: 4m 31s
# 107:	learn: 0.0417867	total: 1m 14s	remaining: 4m 30s
# 108:	learn: 0.0415889	total: 1m 15s	remaining: 4m 29s
# 109:	learn: 0.0412068	total: 1m 15s	remaining: 4m 28s
# 110:	learn: 0.0410335	total: 1m 16s	remaining: 4m 27s
# 111:	learn: 0.0406102	total: 1m 17s	remaining: 4m 26s
# 112:	learn: 0.0402231	total: 1m 17s	remaining: 4m 27s
# 113:	learn: 0.0398920	total: 1m 18s	remaining: 4m 27s
# 114:	learn: 0.0396381	total: 1m 19s	remaining: 4m 27s
# 115:	learn: 0.0392312	total: 1m 20s	remaining: 4m 27s
# 116:	learn: 0.0389321	total: 1m 21s	remaining: 4m 26s
# 117:	learn: 0.0387345	total: 1m 21s	remaining: 4m 24s
# 118:	learn: 0.0384242	total: 1m 22s	remaining: 4m 23s
# 119:	learn: 0.0379190	total: 1m 22s	remaining: 4m 22s
# 120:	learn: 0.0376723	total: 1m 23s	remaining: 4m 21s
# 121:	learn: 0.0373853	total: 1m 24s	remaining: 4m 20s
# 122:	learn: 0.0370477	total: 1m 24s	remaining: 4m 19s
# 123:	learn: 0.0369037	total: 1m 25s	remaining: 4m 17s
# 124:	learn: 0.0366785	total: 1m 25s	remaining: 4m 16s
# 125:	learn: 0.0364567	total: 1m 26s	remaining: 4m 15s
# 126:	learn: 0.0362493	total: 1m 26s	remaining: 4m 14s
# 127:	learn: 0.0359495	total: 1m 27s	remaining: 4m 13s
# 128:	learn: 0.0357548	total: 1m 27s	remaining: 4m 12s
# 129:	learn: 0.0354685	total: 1m 28s	remaining: 4m 11s
# 130:	learn: 0.0352211	total: 1m 28s	remaining: 4m 10s
# 131:	learn: 0.0349280	total: 1m 29s	remaining: 4m 9s
# 132:	learn: 0.0346640	total: 1m 29s	remaining: 4m 8s
# 133:	learn: 0.0344230	total: 1m 30s	remaining: 4m 7s
# 134:	learn: 0.0342100	total: 1m 31s	remaining: 4m 6s
# 135:	learn: 0.0337898	total: 1m 32s	remaining: 4m 6s
# 136:	learn: 0.0333920	total: 1m 32s	remaining: 4m 6s
# 137:	learn: 0.0332047	total: 1m 33s	remaining: 4m 6s
# 138:	learn: 0.0330044	total: 1m 34s	remaining: 4m 6s
# 139:	learn: 0.0327303	total: 1m 35s	remaining: 4m 5s
# 140:	learn: 0.0325657	total: 1m 36s	remaining: 4m 4s
# 141:	learn: 0.0324976	total: 1m 36s	remaining: 4m 3s
# 142:	learn: 0.0323528	total: 1m 37s	remaining: 4m 2s
# 143:	learn: 0.0321061	total: 1m 37s	remaining: 4m 1s
# 144:	learn: 0.0319206	total: 1m 38s	remaining: 4m
# 145:	learn: 0.0317884	total: 1m 38s	remaining: 3m 59s
# 146:	learn: 0.0316094	total: 1m 39s	remaining: 3m 58s
# 147:	learn: 0.0314390	total: 1m 39s	remaining: 3m 57s
# 148:	learn: 0.0310600	total: 1m 40s	remaining: 3m 56s
# 149:	learn: 0.0307817	total: 1m 40s	remaining: 3m 55s
# 150:	learn: 0.0305643	total: 1m 41s	remaining: 3m 54s
# 151:	learn: 0.0304744	total: 1m 42s	remaining: 3m 53s
# 152:	learn: 0.0303238	total: 1m 42s	remaining: 3m 52s
# 153:	learn: 0.0301052	total: 1m 43s	remaining: 3m 51s
# 154:	learn: 0.0299338	total: 1m 43s	remaining: 3m 50s
# 155:	learn: 0.0296479	total: 1m 44s	remaining: 3m 49s
# 156:	learn: 0.0293666	total: 1m 44s	remaining: 3m 48s
# 157:	learn: 0.0291977	total: 1m 45s	remaining: 3m 47s
# 158:	learn: 0.0291228	total: 1m 46s	remaining: 3m 47s
# 159:	learn: 0.0289341	total: 1m 47s	remaining: 3m 47s
# 160:	learn: 0.0288161	total: 1m 47s	remaining: 3m 47s
# 161:	learn: 0.0285855	total: 1m 48s	remaining: 3m 47s
# 162:	learn: 0.0283938	total: 1m 49s	remaining: 3m 47s
# 163:	learn: 0.0283417	total: 1m 50s	remaining: 3m 46s
# 164:	learn: 0.0282437	total: 1m 50s	remaining: 3m 45s
# 165:	learn: 0.0280152	total: 1m 51s	remaining: 3m 44s
# 166:	learn: 0.0277673	total: 1m 51s	remaining: 3m 43s
# 167:	learn: 0.0275214	total: 1m 52s	remaining: 3m 42s
# 168:	learn: 0.0273935	total: 1m 53s	remaining: 3m 41s
# 169:	learn: 0.0271481	total: 1m 53s	remaining: 3m 40s
# 170:	learn: 0.0270381	total: 1m 54s	remaining: 3m 39s
# 171:	learn: 0.0268904	total: 1m 54s	remaining: 3m 38s
# 172:	learn: 0.0266730	total: 1m 55s	remaining: 3m 37s
# 173:	learn: 0.0265513	total: 1m 55s	remaining: 3m 36s
# 174:	learn: 0.0263726	total: 1m 56s	remaining: 3m 35s
# 175:	learn: 0.0261896	total: 1m 56s	remaining: 3m 35s
# 176:	learn: 0.0260316	total: 1m 57s	remaining: 3m 34s
# 177:	learn: 0.0259308	total: 1m 57s	remaining: 3m 33s
# 178:	learn: 0.0258830	total: 1m 58s	remaining: 3m 32s
# 179:	learn: 0.0257935	total: 1m 58s	remaining: 3m 31s
# 180:	learn: 0.0255675	total: 1m 59s	remaining: 3m 30s
# 181:	learn: 0.0254761	total: 2m	remaining: 3m 29s
# 182:	learn: 0.0253247	total: 2m 1s	remaining: 3m 29s
# 183:	learn: 0.0251034	total: 2m 1s	remaining: 3m 29s
# 184:	learn: 0.0249940	total: 2m 2s	remaining: 3m 29s
# 185:	learn: 0.0249201	total: 2m 3s	remaining: 3m 28s
# 186:	learn: 0.0248161	total: 2m 4s	remaining: 3m 28s
# 187:	learn: 0.0247151	total: 2m 5s	remaining: 3m 27s
# 188:	learn: 0.0245981	total: 2m 5s	remaining: 3m 26s
# 189:	learn: 0.0244522	total: 2m 6s	remaining: 3m 25s
# 190:	learn: 0.0243093	total: 2m 6s	remaining: 3m 24s
# 191:	learn: 0.0242165	total: 2m 7s	remaining: 3m 24s
# 192:	learn: 0.0241543	total: 2m 7s	remaining: 3m 23s
# 193:	learn: 0.0239805	total: 2m 8s	remaining: 3m 22s
# 194:	learn: 0.0238588	total: 2m 8s	remaining: 3m 21s
# 195:	learn: 0.0237818	total: 2m 9s	remaining: 3m 20s
# 196:	learn: 0.0235046	total: 2m 9s	remaining: 3m 19s
# 197:	learn: 0.0233992	total: 2m 10s	remaining: 3m 18s
# 198:	learn: 0.0232462	total: 2m 10s	remaining: 3m 18s
# 199:	learn: 0.0231647	total: 2m 11s	remaining: 3m 17s
# 200:	learn: 0.0230300	total: 2m 12s	remaining: 3m 16s
# 201:	learn: 0.0229990	total: 2m 12s	remaining: 3m 15s
# 202:	learn: 0.0227219	total: 2m 13s	remaining: 3m 14s
# 203:	learn: 0.0226300	total: 2m 13s	remaining: 3m 14s
# 204:	learn: 0.0225592	total: 2m 14s	remaining: 3m 13s
# 205:	learn: 0.0224944	total: 2m 15s	remaining: 3m 12s
# 206:	learn: 0.0222872	total: 2m 15s	remaining: 3m 12s
# 207:	learn: 0.0221507	total: 2m 16s	remaining: 3m 11s
# 208:	learn: 0.0220302	total: 2m 17s	remaining: 3m 11s
# 209:	learn: 0.0219194	total: 2m 18s	remaining: 3m 11s
# 210:	learn: 0.0217830	total: 2m 19s	remaining: 3m 11s
# 211:	learn: 0.0216756	total: 2m 20s	remaining: 3m 10s
# 212:	learn: 0.0216290	total: 2m 20s	remaining: 3m 9s
# 213:	learn: 0.0215768	total: 2m 21s	remaining: 3m 8s
# 214:	learn: 0.0215287	total: 2m 21s	remaining: 3m 7s
# 215:	learn: 0.0213845	total: 2m 22s	remaining: 3m 7s
# 216:	learn: 0.0212397	total: 2m 22s	remaining: 3m 6s
# 217:	learn: 0.0211453	total: 2m 23s	remaining: 3m 5s
# 218:	learn: 0.0210786	total: 2m 23s	remaining: 3m 4s
# 219:	learn: 0.0210375	total: 2m 24s	remaining: 3m 3s
# 220:	learn: 0.0209250	total: 2m 24s	remaining: 3m 2s
# 221:	learn: 0.0207741	total: 2m 25s	remaining: 3m 2s
# 222:	learn: 0.0206932	total: 2m 26s	remaining: 3m 1s
# 223:	learn: 0.0205617	total: 2m 26s	remaining: 3m
# 224:	learn: 0.0204870	total: 2m 27s	remaining: 2m 59s
# 225:	learn: 0.0203760	total: 2m 27s	remaining: 2m 58s
# 226:	learn: 0.0203434	total: 2m 28s	remaining: 2m 58s
# 227:	learn: 0.0202298	total: 2m 28s	remaining: 2m 57s
# 228:	learn: 0.0201395	total: 2m 29s	remaining: 2m 56s
# 229:	learn: 0.0199971	total: 2m 29s	remaining: 2m 56s
# 230:	learn: 0.0199221	total: 2m 30s	remaining: 2m 55s
# 231:	learn: 0.0197897	total: 2m 31s	remaining: 2m 55s
# 232:	learn: 0.0197171	total: 2m 32s	remaining: 2m 54s
# 233:	learn: 0.0196722	total: 2m 33s	remaining: 2m 54s
# 234:	learn: 0.0195389	total: 2m 34s	remaining: 2m 54s
# 235:	learn: 0.0194680	total: 2m 34s	remaining: 2m 53s
# 236:	learn: 0.0193703	total: 2m 35s	remaining: 2m 52s
# 237:	learn: 0.0193225	total: 2m 35s	remaining: 2m 51s
# 238:	learn: 0.0192411	total: 2m 36s	remaining: 2m 50s
# 239:	learn: 0.0191533	total: 2m 37s	remaining: 2m 50s
# 240:	learn: 0.0190852	total: 2m 37s	remaining: 2m 49s
# 241:	learn: 0.0190083	total: 2m 38s	remaining: 2m 48s
# 242:	learn: 0.0189522	total: 2m 38s	remaining: 2m 47s
# 243:	learn: 0.0189026	total: 2m 39s	remaining: 2m 46s
# 244:	learn: 0.0187519	total: 2m 39s	remaining: 2m 46s
# 245:	learn: 0.0186560	total: 2m 40s	remaining: 2m 45s
# 246:	learn: 0.0185930	total: 2m 40s	remaining: 2m 44s
# 247:	learn: 0.0185455	total: 2m 41s	remaining: 2m 43s
# 248:	learn: 0.0184403	total: 2m 41s	remaining: 2m 43s
# 249:	learn: 0.0183416	total: 2m 42s	remaining: 2m 42s
# 250:	learn: 0.0183042	total: 2m 42s	remaining: 2m 41s
# 251:	learn: 0.0181902	total: 2m 43s	remaining: 2m 40s
# 252:	learn: 0.0181032	total: 2m 44s	remaining: 2m 40s
# 253:	learn: 0.0179957	total: 2m 44s	remaining: 2m 39s
# 254:	learn: 0.0178986	total: 2m 45s	remaining: 2m 39s
# 255:	learn: 0.0177899	total: 2m 46s	remaining: 2m 38s
# 256:	learn: 0.0177546	total: 2m 47s	remaining: 2m 38s
# 257:	learn: 0.0176238	total: 2m 48s	remaining: 2m 37s
# 258:	learn: 0.0175830	total: 2m 49s	remaining: 2m 37s
# 259:	learn: 0.0175190	total: 2m 49s	remaining: 2m 36s
# 260:	learn: 0.0174228	total: 2m 50s	remaining: 2m 35s
# 261:	learn: 0.0173229	total: 2m 50s	remaining: 2m 35s
# 262:	learn: 0.0172123	total: 2m 51s	remaining: 2m 34s
# 263:	learn: 0.0171617	total: 2m 51s	remaining: 2m 33s
# 264:	learn: 0.0170942	total: 2m 52s	remaining: 2m 32s
# 265:	learn: 0.0170531	total: 2m 52s	remaining: 2m 32s
# 266:	learn: 0.0169413	total: 2m 53s	remaining: 2m 31s
# 267:	learn: 0.0168516	total: 2m 53s	remaining: 2m 30s
# 268:	learn: 0.0168074	total: 2m 54s	remaining: 2m 29s
# 269:	learn: 0.0167189	total: 2m 55s	remaining: 2m 29s
# 270:	learn: 0.0166028	total: 2m 55s	remaining: 2m 28s
# 271:	learn: 0.0165531	total: 2m 56s	remaining: 2m 27s
# 272:	learn: 0.0165097	total: 2m 56s	remaining: 2m 26s
# 273:	learn: 0.0163914	total: 2m 57s	remaining: 2m 26s
# 274:	learn: 0.0162943	total: 2m 57s	remaining: 2m 25s
# 275:	learn: 0.0162613	total: 2m 58s	remaining: 2m 24s
# 276:	learn: 0.0162149	total: 2m 58s	remaining: 2m 24s
# 277:	learn: 0.0161884	total: 2m 59s	remaining: 2m 23s
# 278:	learn: 0.0160746	total: 3m	remaining: 2m 23s
# 279:	learn: 0.0160092	total: 3m 1s	remaining: 2m 22s
# 280:	learn: 0.0159815	total: 3m 2s	remaining: 2m 22s
# 281:	learn: 0.0159217	total: 3m 3s	remaining: 2m 21s
# 282:	learn: 0.0158424	total: 3m 3s	remaining: 2m 21s
# 283:	learn: 0.0157990	total: 3m 4s	remaining: 2m 20s
# 284:	learn: 0.0157294	total: 3m 5s	remaining: 2m 19s
# 285:	learn: 0.0156594	total: 3m 5s	remaining: 2m 18s
# 286:	learn: 0.0156168	total: 3m 6s	remaining: 2m 18s
# 287:	learn: 0.0155474	total: 3m 6s	remaining: 2m 17s
# 288:	learn: 0.0154990	total: 3m 7s	remaining: 2m 16s
# 289:	learn: 0.0154370	total: 3m 7s	remaining: 2m 15s
# 290:	learn: 0.0153820	total: 3m 8s	remaining: 2m 15s
# 291:	learn: 0.0153113	total: 3m 8s	remaining: 2m 14s
# 292:	learn: 0.0151950	total: 3m 9s	remaining: 2m 13s
# 293:	learn: 0.0151576	total: 3m 9s	remaining: 2m 13s
# 294:	learn: 0.0151038	total: 3m 10s	remaining: 2m 12s
# 295:	learn: 0.0150235	total: 3m 11s	remaining: 2m 11s
# 296:	learn: 0.0149675	total: 3m 11s	remaining: 2m 10s
# 297:	learn: 0.0149172	total: 3m 12s	remaining: 2m 10s
# 298:	learn: 0.0148546	total: 3m 12s	remaining: 2m 9s
# 299:	learn: 0.0147629	total: 3m 13s	remaining: 2m 8s
# 300:	learn: 0.0147183	total: 3m 13s	remaining: 2m 8s
# 301:	learn: 0.0146829	total: 3m 14s	remaining: 2m 7s
# 302:	learn: 0.0146172	total: 3m 15s	remaining: 2m 7s
# 303:	learn: 0.0145447	total: 3m 16s	remaining: 2m 6s
# 304:	learn: 0.0144561	total: 3m 17s	remaining: 2m 6s
# 305:	learn: 0.0144088	total: 3m 18s	remaining: 2m 5s
# 306:	learn: 0.0143752	total: 3m 18s	remaining: 2m 5s
# 307:	learn: 0.0143324	total: 3m 19s	remaining: 2m 4s
# 308:	learn: 0.0143120	total: 3m 19s	remaining: 2m 3s
# 309:	learn: 0.0142786	total: 3m 20s	remaining: 2m 2s
# 310:	learn: 0.0142228	total: 3m 21s	remaining: 2m 2s
# 311:	learn: 0.0141239	total: 3m 21s	remaining: 2m 1s
# 312:	learn: 0.0140829	total: 3m 22s	remaining: 2m
# 313:	learn: 0.0140444	total: 3m 22s	remaining: 2m
# 314:	learn: 0.0139694	total: 3m 23s	remaining: 1m 59s
# 315:	learn: 0.0139305	total: 3m 23s	remaining: 1m 58s
# 316:	learn: 0.0138819	total: 3m 24s	remaining: 1m 57s
# 317:	learn: 0.0137822	total: 3m 24s	remaining: 1m 57s
# 318:	learn: 0.0137106	total: 3m 25s	remaining: 1m 56s
# 319:	learn: 0.0136598	total: 3m 25s	remaining: 1m 55s
# 320:	learn: 0.0135951	total: 3m 26s	remaining: 1m 55s
# 321:	learn: 0.0135693	total: 3m 26s	remaining: 1m 54s
# 322:	learn: 0.0135298	total: 3m 27s	remaining: 1m 53s
# 323:	learn: 0.0134758	total: 3m 28s	remaining: 1m 53s
# 324:	learn: 0.0134424	total: 3m 28s	remaining: 1m 52s
# 325:	learn: 0.0134109	total: 3m 29s	remaining: 1m 51s
# 326:	learn: 0.0133804	total: 3m 30s	remaining: 1m 51s
# 327:	learn: 0.0133258	total: 3m 31s	remaining: 1m 50s
# 328:	learn: 0.0133122	total: 3m 32s	remaining: 1m 50s
# 329:	learn: 0.0132565	total: 3m 33s	remaining: 1m 49s
# 330:	learn: 0.0132169	total: 3m 33s	remaining: 1m 49s
# 331:	learn: 0.0131943	total: 3m 34s	remaining: 1m 48s
# 332:	learn: 0.0131575	total: 3m 34s	remaining: 1m 47s
# 333:	learn: 0.0131210	total: 3m 35s	remaining: 1m 46s
# 334:	learn: 0.0130994	total: 3m 35s	remaining: 1m 46s
# 335:	learn: 0.0130827	total: 3m 36s	remaining: 1m 45s
# 336:	learn: 0.0130546	total: 3m 36s	remaining: 1m 44s
# 337:	learn: 0.0130077	total: 3m 37s	remaining: 1m 44s
# 338:	learn: 0.0129506	total: 3m 37s	remaining: 1m 43s
# 339:	learn: 0.0129154	total: 3m 38s	remaining: 1m 42s
# 340:	learn: 0.0128975	total: 3m 39s	remaining: 1m 42s
# 341:	learn: 0.0128332	total: 3m 39s	remaining: 1m 41s
# 342:	learn: 0.0127822	total: 3m 40s	remaining: 1m 40s
# 343:	learn: 0.0127666	total: 3m 40s	remaining: 1m 40s
# 344:	learn: 0.0127493	total: 3m 41s	remaining: 1m 39s
# 345:	learn: 0.0127064	total: 3m 41s	remaining: 1m 38s
# 346:	learn: 0.0126822	total: 3m 42s	remaining: 1m 37s
# 347:	learn: 0.0126176	total: 3m 42s	remaining: 1m 37s
# 348:	learn: 0.0125795	total: 3m 43s	remaining: 1m 36s
# 349:	learn: 0.0125397	total: 3m 44s	remaining: 1m 36s
# 350:	learn: 0.0125145	total: 3m 45s	remaining: 1m 35s
# 351:	learn: 0.0124649	total: 3m 47s	remaining: 1m 35s
# 352:	learn: 0.0124099	total: 3m 48s	remaining: 1m 35s
# 353:	learn: 0.0123963	total: 3m 48s	remaining: 1m 34s
# 354:	learn: 0.0123391	total: 3m 49s	remaining: 1m 33s
# 355:	learn: 0.0123084	total: 3m 49s	remaining: 1m 32s
# 356:	learn: 0.0122719	total: 3m 50s	remaining: 1m 32s
# 357:	learn: 0.0122600	total: 3m 50s	remaining: 1m 31s
# 358:	learn: 0.0122251	total: 3m 51s	remaining: 1m 30s
# 359:	learn: 0.0121746	total: 3m 51s	remaining: 1m 30s
# 360:	learn: 0.0121352	total: 3m 52s	remaining: 1m 29s
# 361:	learn: 0.0120961	total: 3m 53s	remaining: 1m 28s
# 362:	learn: 0.0120345	total: 3m 53s	remaining: 1m 28s
# 363:	learn: 0.0120198	total: 3m 54s	remaining: 1m 27s
# 364:	learn: 0.0120077	total: 3m 54s	remaining: 1m 26s
# 365:	learn: 0.0119734	total: 3m 55s	remaining: 1m 26s
# 366:	learn: 0.0119307	total: 3m 55s	remaining: 1m 25s
# 367:	learn: 0.0118865	total: 3m 56s	remaining: 1m 24s
# 368:	learn: 0.0118295	total: 3m 56s	remaining: 1m 24s
# 369:	learn: 0.0117942	total: 3m 57s	remaining: 1m 23s
# 370:	learn: 0.0117439	total: 3m 57s	remaining: 1m 22s
# 371:	learn: 0.0117082	total: 3m 58s	remaining: 1m 22s
# 372:	learn: 0.0116718	total: 3m 59s	remaining: 1m 21s
# 373:	learn: 0.0116515	total: 4m	remaining: 1m 20s
# 374:	learn: 0.0116282	total: 4m 1s	remaining: 1m 20s
# 375:	learn: 0.0115881	total: 4m 2s	remaining: 1m 19s
# 376:	learn: 0.0115410	total: 4m 2s	remaining: 1m 19s
# 377:	learn: 0.0115232	total: 4m 3s	remaining: 1m 18s
# 378:	learn: 0.0114833	total: 4m 3s	remaining: 1m 17s
# 379:	learn: 0.0114069	total: 4m 4s	remaining: 1m 17s
# 380:	learn: 0.0113573	total: 4m 5s	remaining: 1m 16s
# 381:	learn: 0.0113387	total: 4m 5s	remaining: 1m 15s
# 382:	learn: 0.0113108	total: 4m 6s	remaining: 1m 15s
# 383:	learn: 0.0112591	total: 4m 6s	remaining: 1m 14s
# 384:	learn: 0.0111887	total: 4m 7s	remaining: 1m 13s
# 385:	learn: 0.0111416	total: 4m 7s	remaining: 1m 13s
# 386:	learn: 0.0111195	total: 4m 8s	remaining: 1m 12s
# 387:	learn: 0.0110935	total: 4m 8s	remaining: 1m 11s
# 388:	learn: 0.0110407	total: 4m 9s	remaining: 1m 11s
# 389:	learn: 0.0109896	total: 4m 9s	remaining: 1m 10s
# 390:	learn: 0.0109626	total: 4m 10s	remaining: 1m 9s
# 391:	learn: 0.0109309	total: 4m 10s	remaining: 1m 9s
# 392:	learn: 0.0108919	total: 4m 11s	remaining: 1m 8s
# 393:	learn: 0.0108485	total: 4m 12s	remaining: 1m 7s
# 394:	learn: 0.0107855	total: 4m 12s	remaining: 1m 7s
# 395:	learn: 0.0107688	total: 4m 13s	remaining: 1m 6s
# 396:	learn: 0.0107253	total: 4m 14s	remaining: 1m 5s
# 397:	learn: 0.0106647	total: 4m 15s	remaining: 1m 5s
# 398:	learn: 0.0106238	total: 4m 16s	remaining: 1m 4s
# 399:	learn: 0.0105928	total: 4m 16s	remaining: 1m 4s
# 400:	learn: 0.0105544	total: 4m 17s	remaining: 1m 3s
# 401:	learn: 0.0105298	total: 4m 18s	remaining: 1m 2s
# 402:	learn: 0.0105093	total: 4m 18s	remaining: 1m 2s
# 403:	learn: 0.0104712	total: 4m 19s	remaining: 1m 1s
# 404:	learn: 0.0104487	total: 4m 19s	remaining: 1m
# 405:	learn: 0.0104171	total: 4m 20s	remaining: 1m
# 406:	learn: 0.0103557	total: 4m 20s	remaining: 59.6s
# 407:	learn: 0.0103299	total: 4m 21s	remaining: 59s
# 408:	learn: 0.0102783	total: 4m 22s	remaining: 58.3s
# 409:	learn: 0.0102639	total: 4m 22s	remaining: 57.6s
# 410:	learn: 0.0102012	total: 4m 23s	remaining: 57s
# 411:	learn: 0.0101772	total: 4m 23s	remaining: 56.3s
# 412:	learn: 0.0101396	total: 4m 24s	remaining: 55.7s
# 413:	learn: 0.0101122	total: 4m 24s	remaining: 55s
# 414:	learn: 0.0100804	total: 4m 25s	remaining: 54.3s
# 415:	learn: 0.0100574	total: 4m 25s	remaining: 53.7s
# 416:	learn: 0.0100420	total: 4m 26s	remaining: 53s
# 417:	learn: 0.0100296	total: 4m 26s	remaining: 52.4s
# 418:	learn: 0.0100109	total: 4m 27s	remaining: 51.7s
# 419:	learn: 0.0099798	total: 4m 28s	remaining: 51.1s
# 420:	learn: 0.0099451	total: 4m 29s	remaining: 50.5s
# 421:	learn: 0.0099251	total: 4m 30s	remaining: 49.9s
# 422:	learn: 0.0098866	total: 4m 31s	remaining: 49.3s
# 423:	learn: 0.0098407	total: 4m 31s	remaining: 48.7s
# 424:	learn: 0.0098219	total: 4m 32s	remaining: 48.1s
# 425:	learn: 0.0098100	total: 4m 33s	remaining: 47.4s
# 426:	learn: 0.0097713	total: 4m 33s	remaining: 46.8s
# 427:	learn: 0.0097555	total: 4m 34s	remaining: 46.1s
# 428:	learn: 0.0097296	total: 4m 34s	remaining: 45.5s
# 429:	learn: 0.0097080	total: 4m 35s	remaining: 44.8s
# 430:	learn: 0.0096707	total: 4m 35s	remaining: 44.1s
# 431:	learn: 0.0096446	total: 4m 36s	remaining: 43.5s
# 432:	learn: 0.0096125	total: 4m 36s	remaining: 42.8s
# 433:	learn: 0.0095900	total: 4m 37s	remaining: 42.2s
# 434:	learn: 0.0095570	total: 4m 37s	remaining: 41.5s
# 435:	learn: 0.0095433	total: 4m 38s	remaining: 40.9s
# 436:	learn: 0.0095036	total: 4m 38s	remaining: 40.2s
# 437:	learn: 0.0094702	total: 4m 39s	remaining: 39.6s
# 438:	learn: 0.0094182	total: 4m 40s	remaining: 38.9s
# 439:	learn: 0.0093693	total: 4m 40s	remaining: 38.3s
# 440:	learn: 0.0093507	total: 4m 41s	remaining: 37.6s
# 441:	learn: 0.0093369	total: 4m 41s	remaining: 37s
# 442:	learn: 0.0093080	total: 4m 42s	remaining: 36.3s
# 443:	learn: 0.0092847	total: 4m 43s	remaining: 35.7s
# 444:	learn: 0.0092621	total: 4m 44s	remaining: 35.1s
# 445:	learn: 0.0092300	total: 4m 45s	remaining: 34.5s
# 446:	learn: 0.0092100	total: 4m 45s	remaining: 33.9s
# 447:	learn: 0.0091699	total: 4m 46s	remaining: 33.3s
# 448:	learn: 0.0091411	total: 4m 47s	remaining: 32.6s
# 449:	learn: 0.0091265	total: 4m 47s	remaining: 32s
# 450:	learn: 0.0091063	total: 4m 48s	remaining: 31.3s
# 451:	learn: 0.0090840	total: 4m 48s	remaining: 30.7s
# 452:	learn: 0.0090324	total: 4m 49s	remaining: 30s
# 453:	learn: 0.0090104	total: 4m 50s	remaining: 29.4s
# 454:	learn: 0.0089943	total: 4m 50s	remaining: 28.7s
# 455:	learn: 0.0089721	total: 4m 51s	remaining: 28.1s
# 456:	learn: 0.0089480	total: 4m 51s	remaining: 27.4s
# 457:	learn: 0.0089158	total: 4m 52s	remaining: 26.8s
# 458:	learn: 0.0088833	total: 4m 52s	remaining: 26.1s
# 459:	learn: 0.0088654	total: 4m 53s	remaining: 25.5s
# 460:	learn: 0.0088322	total: 4m 53s	remaining: 24.9s
# 461:	learn: 0.0088072	total: 4m 54s	remaining: 24.2s
# 462:	learn: 0.0087814	total: 4m 54s	remaining: 23.6s
# 463:	learn: 0.0087647	total: 4m 55s	remaining: 22.9s
# 464:	learn: 0.0087431	total: 4m 55s	remaining: 22.3s
# 465:	learn: 0.0087129	total: 4m 56s	remaining: 21.6s
# 466:	learn: 0.0086816	total: 4m 57s	remaining: 21s
# 467:	learn: 0.0086574	total: 4m 58s	remaining: 20.4s
# 468:	learn: 0.0086350	total: 4m 58s	remaining: 19.8s
# 469:	learn: 0.0086152	total: 4m 59s	remaining: 19.1s
# 470:	learn: 0.0085734	total: 5m	remaining: 18.5s
# 471:	learn: 0.0085562	total: 5m 1s	remaining: 17.9s
# 472:	learn: 0.0085403	total: 5m 2s	remaining: 17.3s
# 473:	learn: 0.0085280	total: 5m 3s	remaining: 16.7s
# 474:	learn: 0.0085111	total: 5m 4s	remaining: 16s
# 475:	learn: 0.0084904	total: 5m 5s	remaining: 15.4s
# 476:	learn: 0.0084628	total: 5m 6s	remaining: 14.8s
# 477:	learn: 0.0084031	total: 5m 6s	remaining: 14.1s
# 478:	learn: 0.0083714	total: 5m 7s	remaining: 13.5s
# 479:	learn: 0.0083351	total: 5m 7s	remaining: 12.8s
# 480:	learn: 0.0083154	total: 5m 8s	remaining: 12.2s
# 481:	learn: 0.0083061	total: 5m 9s	remaining: 11.5s
# 482:	learn: 0.0082868	total: 5m 10s	remaining: 10.9s
# 483:	learn: 0.0082603	total: 5m 10s	remaining: 10.3s
# 484:	learn: 0.0082363	total: 5m 11s	remaining: 9.64s
# 485:	learn: 0.0082135	total: 5m 12s	remaining: 9.01s
# 486:	learn: 0.0081823	total: 5m 13s	remaining: 8.38s
# 487:	learn: 0.0081600	total: 5m 14s	remaining: 7.74s
# 488:	learn: 0.0081334	total: 5m 15s	remaining: 7.1s
# 489:	learn: 0.0081188	total: 5m 16s	remaining: 6.46s
# 490:	learn: 0.0081031	total: 5m 17s	remaining: 5.82s
# 491:	learn: 0.0080751	total: 5m 18s	remaining: 5.17s
# 492:	learn: 0.0080588	total: 5m 18s	remaining: 4.52s
# 493:	learn: 0.0080349	total: 5m 19s	remaining: 3.88s
# 494:	learn: 0.0080227	total: 5m 19s	remaining: 3.23s
# 495:	learn: 0.0080020	total: 5m 20s	remaining: 2.58s
# 496:	learn: 0.0079895	total: 5m 20s	remaining: 1.94s
# 497:	learn: 0.0079678	total: 5m 21s	remaining: 1.29s
# 498:	learn: 0.0079378	total: 5m 21s	remaining: 645ms
# 499:	learn: 0.0079036	total: 5m 22s	remaining: 0us
# CatBoost Accuracy: 0.9855072463768116

# %% [markdown]
# ## MLPClassifier

# %%
# Define neural network MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(256, 128, 64), activation="relu", solver="adam", max_iter=500)

# Train model
mlp.fit(X_train, y_train)

# Predict and evaluate
y_pred_mlp = mlp.predict(X_test)

# Save model
joblib.dump(mlp, os.path.join(save_dir, f"mlp_model.pkl"))

print("MLPClassifier Accuracy:", mlp.score(X_test, y_test))
# Out:
# MLPClassifier Accuracy: 0.9895833333333334

# %% [markdown]
# ## Deep Neural Network (DNN)
#
# A Deep Neural Network (DNN) is a powerful machine learning model that can learn complex relationships in data. In this project, we use DNN to classify customer inquiries based on text embeddings generated from interactions.
#
# **Key benefits**
# - Understands subtle differences in customer inquiries better than traditional models.
# - Works well with 384D SBERT embeddings without needing dimensionality reduction.
# - Can handle increasing customer interactions and be improved over time.
# - Uses RandomizedSearchCV to optimize parameters like learning rate, activation functions, and batch size.

# %%
# Define DNN Model Using Functional API
def build_dnn_model(input_dim, num_classes):
    inputs = layers.Input(shape=(input_dim,))  # Explicit Input layer
    x = layers.Dense(256, activation="relu")(inputs)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)  # Output layer

    model = Model(inputs=inputs, outputs=outputs)  # Define Model

    # Compile model
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# Define model
input_dim = X_train.shape[1]  # Number of input features (SBERT embedding size)
num_classes = len(set(y_train))  # Number of classes
dnn_model = build_dnn_model(input_dim, num_classes)

# Train DNN
dnn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=32)

# Evaluate performance
test_loss, test_acc = dnn_model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# Epoch 1/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8234 - loss: 0.7450 - val_accuracy: 0.9769 - val_loss: 0.0722
# Epoch 2/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9816 - loss: 0.0592 - val_accuracy: 0.9819 - val_loss: 0.0608
# Epoch 3/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9863 - loss: 0.0419 - val_accuracy: 0.9823 - val_loss: 0.0524
# Epoch 4/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9878 - loss: 0.0312 - val_accuracy: 0.9769 - val_loss: 0.0754
# Epoch 5/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9884 - loss: 0.0311 - val_accuracy: 0.9769 - val_loss: 0.0767
# Epoch 6/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9920 - loss: 0.0203 - val_accuracy: 0.9805 - val_loss: 0.0521
# Epoch 7/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9944 - loss: 0.0172 - val_accuracy: 0.9873 - val_loss: 0.0410
# Epoch 8/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9964 - loss: 0.0093 - val_accuracy: 0.9823 - val_loss: 0.0585
# Epoch 9/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9976 - loss: 0.0062 - val_accuracy: 0.9846 - val_loss: 0.0622
# Epoch 10/10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9860 - val_loss: 0.0426
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0500
# Test Accuracy: 0.9859601259231567

# %%
# Save model
joblib.dump(dnn_model, os.path.join(save_dir, f"dnn_model.pkl"))
# Out:
# ['/content/drive/MyDrive/Colab_Notebooks/financial_customer_inq/models/dnn_model.pkl']

# %%
# Define the directory path
save_dir = '/content/drive/MyDrive/Colab_Notebooks/financial_customer_inq/models/'

# List of models to load
model_filenames = {
    "XGBoost": "xgb_model.pkl",
    "CatBoost": "cat_model.pkl",
    "MLP": "mlp_model.pkl",
    "DNN": "dnn_model.pkl",
    "SVC": "SVC_best_model.pkl",
    "Logistic Regression": "LogisticRegression_best_model.pkl",
    "LightGBM": "LGBMClassifier_best_model.pkl",
    "Random Forest": "RandomForestClassifier_best_model.pkl"
}

# Load models
models = {name: joblib.load(os.path.join(save_dir, filename)) for name, filename in model_filenames.items()}

# Dictionary to store classification reports
classification_reports = {}

# Evaluate each model
for model_name, model in models.items():
    y_pred = model.predict(X_test)

    # Convert probability outputs to class labels if necessary
    if y_pred.ndim > 1 and y_pred.shape[1] > 1:  # Check if model outputs probabilities
        y_pred = np.argmax(y_pred, axis=1)  # Convert to class labels

    # Generate classification report
    report = classification_report(y_test, y_pred, output_dict=True)
    classification_reports[model_name] = report["weighted avg"]  # Store only weighted avg metrics

# Convert results to DataFrame
df_results = pd.DataFrame.from_dict(classification_reports, orient="index")

# Display results
print("\nModel Performance Comparison:")
print(df_results)

# Save results to CSV for reference
df_results.to_csv("model_classification_reports.csv", index=True)

print("\nClassification reports saved as 'model_classification_reports.csv'")
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Model Performance Comparison:
#                      precision    recall  f1-score  support
# XGBoost               0.981708  0.981884  0.981364   2208.0
# CatBoost              0.985652  0.985507  0.985375   2208.0
# MLP                   0.989474  0.989583  0.989492   2208.0
# DNN                   0.986122  0.985960  0.985889   2208.0
# SVC                   0.991463  0.991395  0.991420   2208.0
# Logistic Regression   0.989109  0.989130  0.989112   2208.0
# LightGBM              0.985153  0.985054  0.984708   2208.0
# Random Forest         0.975099  0.978261  0.975759   2208.0
#
# Classification reports saved as 'model_classification_reports.csv'
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Summary
#
# - Trained multiple classification models XGBoost, CatBoost, MLP, DNN, SVC, Logistic Regression, LightGBM, and Random Forest for customer inquiry categorization.
# - Optimized models with hyperparameter tuning with GridSearchCV.
# - Evaluated models using accuracy, precision, recall, and F1-score.
# - The well tuned SVC model with GridSearch has the best accuracy score by 0.9935.
